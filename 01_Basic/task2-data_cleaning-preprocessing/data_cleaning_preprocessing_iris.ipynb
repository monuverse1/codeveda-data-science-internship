# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder, StandardScaler

# Load dataset
df = pd.read_csv("iris.csv")

# Display original data
print("Original Data:\n", df.head())

# Check missing values
print("\nMissing Values:\n", df.isnull().sum())

# Handle missing values
df.fillna(df.mean(numeric_only=True), inplace=True)

# Convert categorical to numerical
le = LabelEncoder()
df['species'] = le.fit_transform(df['species'])

# Remove outliers using IQR
Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR = Q3 - Q1

df = df[~((df < (Q1 - 1.5 * IQR)) | (df > (Q3 + 1.5 * IQR))).any(axis=1)]

# Normalize data
scaler = StandardScaler()
df_scaled = scaler.fit_transform(df)

df = pd.DataFrame(df_scaled, columns=df.columns)

# Final cleaned data
print("\nCleaned Data:\n", df.head())
print("\nDataset Info:")
print(df.info())
df.to_csv("cleaned_iris.csv", index=False)
# Out:
# Original Data:
#     sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
#
# Missing Values:
#  sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64
#
# Cleaned Data:
#     sepal_length  sepal_width  petal_length  petal_width   species
# 0     -0.910515     1.175789     -1.374878    -1.345899 -1.252455
# 1     -1.151122    -0.093924     -1.374878    -1.345899 -1.252455
# 2     -1.391729     0.413961     -1.431986    -1.345899 -1.252455
# 3     -1.512032     0.160019     -1.317771    -1.345899 -1.252455
# 4     -1.030819     1.429732     -1.374878    -1.345899 -1.252455
#
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146 entries, 0 to 145
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  146 non-null    float64
#  1   sepal_width   146 non-null    float64
#  2   petal_length  146 non-null    float64
#  3   petal_width   146 non-null    float64
#  4   species       146 non-null    float64
# dtypes: float64(5)
# memory usage: 5.8 KB
# None
